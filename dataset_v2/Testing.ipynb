# %%
import numpy as np
import os

data_dir = "/users/jboskovi/sionna_project/sionna_osm_scene/dataset_v2/dataset_3m"
files = sorted(os.listdir(data_dir))
print(f"Files saved: {files}")

# Load and inspect first sample
data = np.load(os.path.join(data_dir, files[0]))
print(f"\nSample 0:")
print(f"  sensor_pos: {data['sensor_pos']}")
print(f"  rss_map shape: {data['rss_map'].shape}")
print(f"  coverage_map shape: {data['coverage_map'].shape}")
print(f"  rss_map range: {data['rss_map'].min():.2f} to {data['rss_map'].max():.2f} dBm")
print(f"  coverage: {data['coverage_map'].sum()} / {data['coverage_map'].size} cells")
# Out:
# Files saved: ['sample_0000.npz', 'sample_0001.npz', 'sample_0002.npz']
#
# Sample 0:
#   sensor_pos: [ -84.  -131.2   10. ]
#   rss_map shape: (110, 70)
#   coverage_map shape: (110, 70)
#   rss_map range: -180.00 to -39.59 dBm
#   coverage: 2620 / 7700 cells
